# %%
from deta import Deta
import pandas as pd
import numpy as np

# %%
class StockyDb:
    def __init__(self):
        self.deta = Deta('d0p5if1f_GSnmoPk32YPhwKaJzN6sq7hM2DN4XPks')
        self.db = self.deta.Base('StockyAI')
        
    def save_to_DB(self,ticker,df):
        date_=[]
        open_=[]
        high_=[]
        low_=[]
        close_=[]
        for i in range (0,len(df)):
            df['Close']=df['Close'].astype(float)
            df['Low']=df['Low'].astype(float)
            df['High']=df['High'].astype(float)
            df['Open']=df['Open'].astype(float)
            date_.append(df['Date'][i])
            open_.append(df['Open'][i])
            high_.append(df['High'][i])
            low_.append(df['Low'][i])
            close_.append(df['Close'][i])
        self.db.put({'key':ticker,'date':date_,'open':open_,'high':high_,'low':low_,'close':close_})
    
    def ticker_df(self,ticker):
        return self.db.get(key=ticker)
    
    def get_all_ticker(self):
        tickers=[]
        for i in range(0,self.db.fetch().count):
            tickers.append(self.db.fetch().items[i]['key'])
        return tickers

# %%
df = pd.read_csv('test.csv',index_col=False)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
SD = StockyDb()

# %%
SD.save_to_DB("udsu",df)

# %%
SD.get_all_ticker()
# Out:
# ['RELIANCE.NS', 'TATAMOTORS.NS']

# %%
Tdic=SD.ticker_df('RELIANCE.NS')

# %%
Tdf.head(5)
# Out:
#          close        date         high          key          low         open
# 0  2565.350586  2022-11-28  2554.479004  RELIANCE.NS  2560.783936  2531.567139
# 1  2585.606445  2022-11-29  2584.776367  RELIANCE.NS  2590.989014  2570.535645
# 2  2590.278564  2022-11-30  2584.825684  RELIANCE.NS  2599.659668  2582.841553
# 3  2602.883545  2022-12-01  2593.745605  RELIANCE.NS  2607.821533  2591.947754
# 4  2583.056885  2022-12-02  2565.169434  RELIANCE.NS  2580.293945  2561.148438

# %%
Tdf=Tdf[['date','open','high','low','close']]

# %%
S_min=Tdf['low'].min()

# %%
S_max=Tdf['high'].max()

# %%
S_min_date = (Tdf[Tdf['low']==S_min])['date'].tolist()
S_max_date = (Tdf[Tdf['high']==S_max])['date'].tolist()

# %%
if S_min_date<S_max_date:
    profit= S_max-S_min
    pro_per = (profit/S_min)*100
    print("Profit in Rs. ",profit," In percent- ",pro_per," %")
# Out:
# Profit in Rs.  170.1708984375  In percent-  6.651505740313772  %

# %%
print(S_min_date)
print(S_max_date)
# Out:
